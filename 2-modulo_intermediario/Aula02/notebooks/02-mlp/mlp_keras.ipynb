# %% [markdown]
# # MLP usando Keras

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
X, y = datasets.make_blobs(n_samples=1000,n_features=2,
                           centers=2,cluster_std=5,
                           random_state=2)#Plotting

fig = plt.figure(figsize=(10,8))
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'r^')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
# splitting the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.10, random_state = 1,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation

model = Sequential()

model.add(Dense(128, activation = 'sigmoid', input_dim = 2))
model.add(Dense(64, activation = 'sigmoid'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(optimizer='sgd',loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## Training

# %%
history = model.fit(X_train, y_train, epochs = 30)
# Out:
# Epoch 1/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.7229 - accuracy: 0.5022
# Epoch 2/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6792 - accuracy: 0.5978
# Epoch 3/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6608 - accuracy: 0.6756
# Epoch 4/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6447 - accuracy: 0.7800
# Epoch 5/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6294 - accuracy: 0.8044
# Epoch 6/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6151 - accuracy: 0.8022
# Epoch 7/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.6020 - accuracy: 0.7956
# Epoch 8/30
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5894 - accuracy: 0.8178
# Epoch 9/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5776 - accuracy: 0.8078
# Epoch 10/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5672 - accuracy: 0.8133
# Epoch 11/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5570 - accuracy: 0.8056
# Epoch 12/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5477 - accuracy: 0.8089
# Epoch 13/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5396 - accuracy: 0.8167
# Epoch 14/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5307 - accuracy: 0.8000
# Epoch 15/30
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5231 - accuracy: 0.8122
# Epoch 16/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5163 - accuracy: 0.8044
# Epoch 17/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5097 - accuracy: 0.8000
# Epoch 18/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5033 - accuracy: 0.8111
# Epoch 19/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4974 - accuracy: 0.8056
# Epoch 20/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4917 - accuracy: 0.8167
# Epoch 21/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4868 - accuracy: 0.8078
# Epoch 22/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4832 - accuracy: 0.7989
# Epoch 23/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.8056
# Epoch 24/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4748 - accuracy: 0.8056
# Epoch 25/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4711 - accuracy: 0.8100
# Epoch 26/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8122
# Epoch 27/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.8111
# Epoch 28/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.8089
# Epoch 29/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.8156
# Epoch 30/30
# 29/29 [==============================] - 0s 2ms/step - loss: 0.4563 - accuracy: 0.8111

# %% [markdown]
# ## Prediction

# %%
y_pred = model.predict(X_test)
y_pred.shape
# Out:
# (100, 1)

# %%
y_pred = (y_pred > 0.5).astype("int32")

# %%
y_pred = y_pred.reshape(y_pred.shape[0], )

# %%
fig = plt.figure(figsize=(10,8))
plt.plot(X_test[:, 0][y_test == 0], X_test[:, 1][y_test == 0], 'r^')
plt.plot(X_test[:, 0][y_test == 1], X_test[:, 1][y_test == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')

# %%
fig = plt.figure(figsize=(10,8))
plt.plot(X_test[:, 0][y_pred == 0], X_test[:, 1][y_pred == 0], 'r^')
plt.plot(X_test[:, 0][y_pred == 1], X_test[:, 1][y_pred == 1], 'bs')
plt.xlabel("feature 1")
plt.ylabel("feature 2")
plt.title('Random Classification Data with 2 classes')
# Out:
# Text(0.5, 1.0, 'Random Classification Data with 2 classes')
