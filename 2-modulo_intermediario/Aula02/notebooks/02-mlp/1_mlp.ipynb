# %%
# https://www.kaggle.com/niyipop/2-layer-neural-network-from-scratch-using-numpy
import numpy as np
import pandas as pd
#import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dasaset

# %%
from sklearn import datasets
X, y = datasets.make_blobs(n_samples=1000, n_features=2, cluster_std=1, centers=2, random_state=42)
#X, y = datasets.make_moons(n_samples=1000, shuffle=True, noise=0.1, random_state=None)

# %%
X.shape
# Out:
# (1000, 2)

# %%
import matplotlib.pyplot as plt
plt.scatter(X[:, 0], X[:, 1], marker='o', c=y,
            s=25, edgecolor='k')

# %%
#Split data to training and validation data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
X.shape
# Out:
# (1000, 2)

# %%
y = y.reshape(-1,1)
y.shape
# Out:
# (1000, 1)

# %% [markdown]
# # Activation Function

# %%
# Sigmoid and its derivative

# %%
input_dims = 2
hidden_dims = 2
output_dims = 1

# %%
# Initialization Weights
w0 = 2 * np.random.random((input_dims, hidden_dims)) -1
w1 = 2 * np.random.random((hidden_dims, output_dims)) -1

# %%
#learning rate
learning_rate = 0.1

#Errors - for graph later
errors = []
# Acc - for graph later
acc = []

epochs = 10

#Train
for i in range(epochs):

    #Feed forward
    layer0 = X

    # Error
    
    
    # Back propagation

    
    #  Gradient descent
    
    
    print('Error: {:.10f} Acc: {}'.format(error, accuracy))
# Out:
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292
# Error: 0.0007924064 Acc: 99.92075936142292

# %%
#Plot the error chart
plt.plot(errors)
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.show()

# %%
#Plot the accuracy chart
plt.plot(acc)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()
print("Training Accuracy " + str(round(accuracy,2)) + "%")
# Out:
# Training Accuracy 99.96%
